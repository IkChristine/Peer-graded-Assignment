# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Christine IK**
# Data Scientist

# %% [markdown]
# *I am interested in data science because I want to apply advanced machine learning and visualization techniques to extract actionable insights from different types of data and address various human issues.*

# %% [markdown]
# ### My code in cell 5 shows the steps to obtain the cube of 5

# %%
5*5*5
# Out:
# 125

# %% [markdown]
# ~Shopping~ `Grocery list`
# ***
#
#   | | Food | Price ($)| Store |
# |---|---|---|---|
# | 1 | Eggs|9|Walmart|
# | 2 | Sugar|6|Publix|
# | 3 | Baking Powder|4|Walmart|
# | 4 | Flour|8|Target|
#
#
# [Search google baking list] (http://google.com)
